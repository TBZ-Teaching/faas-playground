# %% [markdown]
# # Quick Notebook Primer
# A compact intro to VS Code notebooks: run cells top-to-bottom, restart the kernel if state gets odd, and keep outputs close to code.

# %%
import sys
print("Python:", sys.version.split()[0])

# %% [markdown]
# ## Markdown basics
# - Headings, lists, links, and inline math like $e^{i\pi}+1=0$ work here.
# - Use Shift+Enter to run a cell.

# %% [markdown]
# ## Basic code
# Tiny snippets to see outputs inline.

# %%
print("Hello notebook!")
value = (2 + 3) * 2
value

# %% [markdown]
# ## Functions
# Define once, call many times.

# %%
def greet(name: str, excited: bool = False) -> str:
    """Return a friendly greeting."""
    base = f"Hi, {name}!"
    return base + " 🎉" if excited else base

print(greet("Ada"))
print(greet("Linus", excited=True))

# %% [markdown]
# ## OOP basics
# Define a small class with state and behavior.

# %%
class Counter:
    """Minimal counter with increment behavior."""
    def __init__(self, start: int = 0):
        self.value = start

    def increment(self, step: int = 1) -> int:
        self.value += step
        return self.value

c = Counter(5)
print("Start:", c.value)
print("After +1:", c.increment())
print("After +3:", c.increment(3))
